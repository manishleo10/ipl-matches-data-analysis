# %% [markdown]
# # Section 1: Environment setup and data loading.

# %%
# %python
#reading the csv files provided in the zip folder

ipl_ball_by_ball = spark.read.csv(
    "/FileStore/tables/ipl_ball_by_ball.csv", header="true", inferSchema="true"
)
ipl_matches = spark.read.csv(
    "/FileStore/tables/ipl_matches.csv", header="true", inferSchema="true"
)
ipl_venue = spark.read.csv(
    "/FileStore/tables/ipl_venue.csv", header="true", inferSchema="true"
)

ipl_ball_by_ball.cache()  # Cache data for faster reuse
ipl_matches.cache()  # Cache data for faster reuse
ipl_venue.cache()  # Cache data for faster reuse
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: DataFrame[venue_id: int, venue: string, city: string]</div>

# %%
# Creating a table for ipl_ball_by_ball csv

ball_table = "ipl_ball_by_ball_csv"
ipl_ball_by_ball.createOrReplaceTempView(ball_table)
ipl_ball_by_ball.write.format("parquet").saveAsTable(ball_table)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Creating a table for ipl_matches csv

matches_table = "ipl_matches_csv"

ipl_matches.createOrReplaceTempView(matches_table)
ipl_matches.write.format("parquet").saveAsTable(matches_table)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a view or tab# Creating a table for ipl_venue csv

venue_table = "ipl_venue_csv"

ipl_venue.createOrReplaceTempView(venue_table)
ipl_venue.write.format("parquet").saveAsTable(venue_table)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#ipl_ball_by_ball dataframe
display(ipl_ball_by_ball)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#ipl_matches dataframe
display(ipl_matches)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#ipl_venue dataframe
display(ipl_venue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#
spark.sql(
    """
select * from ipl_ball_by_ball_csv
limit 10
"""
).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------+-----+----+-------------+-------------+------------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------+
# match_id|inning|overs|ball|      batsman|  non_striker|      bowler|batsman_runs|extra_runs|total_runs|non_boundary|is_wicket|dismissal_kind|player_dismissed|fielder|extras_type|        batting_team|  bowling_team|
# ...

# %%
ipl_venue.show(vertical=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-RECORD 0------------------------
#  venue_id | 1
#  venue    | Dr. Y.S. Rajasekh...
#  city     | Visakhapatnam
# -RECORD 1------------------------
#  venue_id | 2
#  venue    | Sharjah Cricket S...
#  city     | Sharjah
# -RECORD 2------------------------
#  venue_id | 3
#  venue    | JSCA Internationa...
#  city     | Ranchi
# -RECORD 3------------------------
#  venue_id | 4
#  venue    | Saurashtra Cricke...
#  city     | Rajkot
# -RECORD 4------------------------
#  venue_id | 5
#  venue    | Shaheed Veer Nara...
#  city     | Raipur
# -RECORD 5------------------------
#  venue_id | 6
#  venue    | Maharashtra Crick...
# ...

# %% [markdown]
# # Section 2: Using SparkSQL or pySpark for data analysis

# %% [markdown]
# ## 1. Use SparkSQL or pySpark to analyze the data and answer the following questions.

# %% [markdown]
# ### A. Find the top 3 venues which hosted the most number of eliminator matches?

# %%
spark.sql(
    """
select b.venue,count(b.venue_id) from ipl_matches_csv a
inner join ipl_venue_csv b on a.venue_id=b.venue_id
group by b.venue
order by 2 desc;
"""
).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---------------+
#                venue|count(venue_id)|
# +--------------------+---------------+
# M.Chinnaswamy Sta...|             80|
#         Eden Gardens|             77|
#     Feroz Shah Kotla|             74|
# +--------------------+---------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### B. Return most number of catches taken by a player in IPL history?

# %%
spark.sql(
    """
select fielder,count(*) from ipl_ball_by_ball_csv
where dismissal_kind == 'caught'
group by fielder
order by count(1) desc
limit 1
"""
).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------+
#    fielder|count(1)|
# +----------+--------+
# KD Karthik|     118|
# +----------+--------+
#
# </div>

# %% [markdown]
# ### C. Write a query to return a report for highest wicket taker in matches
# ### which were affected by Duckworth-Lewis’s method (D/L method).

# %%
merged=ipl_ball_by_ball.join(ipl_matches,on='match_id')#merging df and df1 tables
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DL = merged[
    merged["method"] == "D/L"
]  # finding all matches which were effected by D/L method
sum1 = DL.groupBy(["match_id", "batsman"]).sum(
    "batsman_runs"
)  # finding out total runs scored by every batsman in each match effected by D/L
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank
from pyspark.sql.functions import col


window = Window.partitionBy("match_id").orderBy(col("sum(batsman_runs)").desc())
res_4 = sum1.withColumn("rank", rank().over(window))
res_4.filter(res_4.rank == 1).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------------+-----------------+----+
# match_id|     batsman|sum(batsman_runs)|rank|
# +--------+------------+-----------------+----+
#   336022|    V Sehwag|               51|   1|
#   336025| Salman Butt|               73|   1|
#   392183|    V Sehwag|               38|   1|
#   392183|      K Goel|               38|   1|
#   392186|    CH Gayle|               44|   1|
#   392214|   ML Hayden|               89|   1|
#   501215|    SK Raina|               50|   1|
#   501245| S Badrinath|               54|   1|
#   501255|    CH Gayle|               38|   1|
#   733993|  KD Karthik|               39|   1|
# ...

# %% [markdown]
# ### F.
# ### Write a query to return a report for the cricketers with the most number of players of
# ### the match award in neutral venues.

# %%
spark.sql(
    """
select player_of_match,count(player_of_match) from ipl_matches_csv
where neutral_venue = 1
group by player_of_match
order by count(player_of_match) desc 
"""
).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+----------------------+
#  player_of_match|count(player_of_match)|
# +----------------+----------------------+
#        JH Kallis|                     3|
#        JP Duminy|                     3|
#        YK Pathan|                     3|
#       GJ Maxwell|                     3|
#         DR Smith|                     2|
#    KC Sangakkara|                     2|
#        MK Pandey|                     2|
#        RG Sharma|                     2|
#   Sandeep Sharma|                     2|
# DPMD Jayawardene|                     2|
#   M Muralitharan|                     2|
# ...

# %% [markdown]
# ### G. Write a query to get a list of top 10 players with the highest batting average

# %%
player_dismissed = ipl_ball_by_ball.groupby(
    "player_dismissed"
).count()  # Counting number of times a player is dismissed
total_runs = ipl_ball_by_ball.groupBy("batsman").sum("batsman_runs")
joined_data = player_dismissed.join(
    total_runs, player_dismissed.player_dismissed == total_runs.batsman, "inner"
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_7 = joined_data.withColumn(
    "Batsmen Avg", col("sum(batsman_runs)") / col("count")
).sort(
    "Batsmen Avg", ascending=False
)  # Dividing runs by number of times they have been dismissed
result_7.select("batsman", "Batsmen Avg").show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+------------------+
#       batsman|       Batsmen Avg|
# +-------------+------------------+
#    MN van Wyk|55.666666666666664|
#    RD Gaikwad|              51.0|
#      AC Voges|             45.25|
#      KL Rahul| 44.86440677966102|
#       HM Amla| 44.38461538461539|
# Iqbal Abdulla|              44.0|
#     DA Warner| 42.71544715447155|
#   JM Bairstow|41.578947368421055|
#      CH Gayle| 41.13793103448276|
#      MS Dhoni|40.991150442477874|
# +-------------+------------------+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# ### H. Write a query to find out who has officiated (as an umpire) the most number of matches in IPL.

# %%
spark.sql(
    """
select umpire, count(*)
from ((select umpire1 as umpire from ipl_matches_csv) union all
      (select umpire2 from ipl_matches_csv)
     ) ipl_matches_csv
group by umpire
order by count(*) desc ;
"""
).show()
# Combing two similar columns by union and counting numbers on times they have officiated
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------+
#               umpire|count(1)|
# +--------------------+--------+
#               S Ravi|     121|
#      HDPK Dharmasena|      94|
#         AK Chaudhary|      87|
#        C Shamshuddin|      82|
#            M Erasmus|      65|
#          Nitin Menon|      57|
#            CK Nandan|      57|
#           SJA Taufel|      55|
#            Asad Rauf|      51|
#          VA Kulkarni|      50|
#         BNJ Oxenford|      48|
#          CB Gaffaney|      47|
#            RJ Tucker|      46|
#          BR Doctrove|      42|
#          RE Koertzen|      41|
#            Aleem Dar|      38|
# ...

# %% [markdown]
# ### I. Find venue details of the match where V Kohli scored his highest individual runs in
# ### IPL.

# %%
spark.sql(
    """
select m.match_id,first(v.venue),first(v.city),sum(b.batsman_runs) from ipl_ball_by_ball_csv as b
inner join ipl_matches_csv as m on b.match_id=m.match_id
inner join ipl_venue_csv as v on m.venue_id =v.venue_id
where b.batsman= 'V Kohli'
group by m.match_id
order by sum(b.batsman_runs) desc limit 1; 
"""
).show()
# First filtering in matches in which batsman is kohli,grouping by each match and finding total runs by each match and returning them in descending order and limit by 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+--------------------+-----------+-----------------+
# match_id|        first(venue)|first(city)|sum(batsman_runs)|
# +--------+--------------------+-----------+-----------------+
#   980999|M.Chinnaswamy Sta...|  Bengaluru|              113|
# +--------+--------------------+-----------+-----------------+
#
# </div>

# %% [markdown]
# ### J. Creative Case study:
# Please analyze how winning/losing tosses can impact a match and it's result?
# (Bonus for Visualization here)

# %%
ipl_matches
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: DataFrame[match_id: int, date: string, player_of_match: string, venue_id: int, neutral_venue: int, team1: string, team2: string, toss_winner: string, toss_decision: string, winner: string, result: string, result_margin: string, eliminator: string, method: string, umpire1: string, umpire2: string]</div>

# %%
ax=ipl_matches.groupby('toss_winner').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(ax)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
ipl_matches.groupBy('toss_winner').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#          toss_winner|count|
# +--------------------+-----+
#  Sunrisers Hyderabad|   57|
#  Chennai Super Kings|   97|
# Rising Pune Super...|    6|
#      Deccan Chargers|   43|
# Kochi Tuskers Kerala|    8|
#     Rajasthan Royals|   87|
#        Gujarat Lions|   15|
# Royal Challengers...|   87|
# Kolkata Knight Ri...|   98|
# Rising Pune Super...|    7|
#      Kings XI Punjab|   85|
#        Pune Warriors|   20|
#     Delhi Daredevils|   80|
#       Delhi Capitals|   20|
#       Mumbai Indians|  106|
# +--------------------+-----+
#
# </div>

# %%
display(ipl_matches)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.sql("""
SELECT winner, count(winner) FROM ipl_matches_csv as t
    WHERE  t.toss_winner = t.winner
    group by winner
    order by count(winner) desc
""").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------+
#               winner|count(winner)|
# +--------------------+-------------+
#       Mumbai Indians|           61|
#  Chennai Super Kings|           61|
# Kolkata Knight Ri...|           55|
#     Rajasthan Royals|           44|
# Royal Challengers...|           43|
#      Kings XI Punjab|           36|
#     Delhi Daredevils|           35|
#  Sunrisers Hyderabad|           29|
#      Deccan Chargers|           19|
#       Delhi Capitals|           10|
#        Gujarat Lions|           10|
# Rising Pune Super...|            5|
# Kochi Tuskers Kerala|            4|
# ...

# %%
spark.sql("""
SELECT winner, count(winner) FROM ipl_matches_csv as t
    WHERE  t.toss_winner != t.winner
    group by winner
    order by count(winner) desc
""").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------+
#               winner|count(winner)|
# +--------------------+-------------+
#       Mumbai Indians|           59|
#      Kings XI Punjab|           52|
# Royal Challengers...|           48|
#  Chennai Super Kings|           45|
# Kolkata Knight Ri...|           44|
#  Sunrisers Hyderabad|           37|
#     Rajasthan Royals|           37|
#     Delhi Daredevils|           32|
#      Deccan Chargers|           10|
#       Delhi Capitals|            9|
#        Pune Warriors|            9|
# Rising Pune Super...|            5|
#                   NA|            4|
# ...

# %%
spark.sql("""
select count(winner) from ipl_matches_csv as t
where t.winner=t.toss_winner
""").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# count(winner)|
# +-------------+
#           418|
# +-------------+
#
# </div>

# %%
spark.sql("""
select count(winner) from ipl_matches_csv as t
where t.winner!=t.toss_winner
""").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# count(winner)|
# +-------------+
#           398|
# +-------------+
#
# </div>

# %%
display(ipl_matches)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Section 3: Expose Data.

# %% [markdown]
# ### 1. Create a database

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS test_database;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
joined_df = ipl_matches.join(ipl_venue, on=['venue_id'], how='inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Entire_dataset = ipl_ball_by_ball.join(joined_df, on=['match_id'], how='inner')
Entire_dataset.toPandas().to_csv('all_data.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Entire_dataset_table =  "all_data_csv"
Entire_dataset.createOrReplaceTempView("Entire_dataset_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import sqlite3 as sqlt

import pandas as pd

Entire_IPL_Data = pd.read_csv('all_data.csv')

try:
  conn = sqlt.connect('Entire_dataset_table.db')
except:
  pass

Entire_IPL_Data.to_sql('Entire_dataset_table', conn)

Entire_IPL_Data1 = pd.read_sql('SELECT * FROM Entire_dataset_table', conn)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /databricks/python/lib/python3.7/site-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions &lt; 0.14, spaces were converted to underscores.
#   method=method,
# </div>

# %% [markdown]
# ###  2. Create a Class Database.

# %%
class Database:
    def __init__(
        self,
        db_name="Entire_IPL_Data",
    ):
        self.name = db_name
        self.conn = sqlt.connect("Entire_dataset_table.db")

        try:
            self.entire = Entire_IPL_Data.to_sql("Entire_dataset_table", conn)
        except:
            pass

    def get_status(self):  # To get the status of Sqlite database connection
        return self.conn

    def Query_A(self):
        x = sqlContext.sql(
            "select batting_team,match_id,bowling_team,SUM(extra_runs) AS Total_Extra_Runs \
      FROM Entire_dataset_table GROUP BY match_id,bowling_team,batting_team \
      ORDER BY SUM(extra_runs) DESC Limit 1"
        )

        dict1 = {}  # Creating a Dictionary python object

        x = x.toPandas()

        for column in x.columns:
            dict1[column] = x[column].values.tolist()  # Traverse through each column
        return dict1

    def Query_B(self):
        x = sqlContext.sql(
            'select bowler_name,SUM(is_wicket)AS Total_wickets FROM Entire_dataset_table \
      where Not dismissal_kind = "run out" "obstructing the field" \
      GROUP BY bowler_name ORDER BY SUM(is_wicket) DESC Limit 1'
        )

        dict1 = {}  # Creating a Dictionary python object

        x = x.toPandas()

        for column in x.columns:
            dict1[column] = x[column].values.tolist()

        return dict1

    def Query_C(self):
        x = sqlContext.sql(
            " select current_batsman As Player_name,SUM(batsman_runs) AS Total_runs FROM Entire_dataset_table \
      where Dl_method_used = 1 GROUP BY current_batsman ORDER BY SUM(batsman_runs) DESC limit 3"
        )

        dict1 = {}
        x = x.toPandas()
        for column in x.columns:
            dict1[column] = x[column].values.tolist()  # Traverse through each column

        return dict1

    def Query_D(self):

        x = sqlContext.sql(
            'select  current_batsman AS Player_name , Round((sum(batsman_runs)/count(batsman_runs))*100,2) as Strike_rate \
      from Entire_dataset_table where current_over between 1 and 6 AND  extras_type = "NA" \
      GROUP BY current_batsman ORDER BY Strike_rate DESC Limit 1'
        )

        dict1 = {}  # Creating a Dictionary python object

        x = x.toPandas()

        for column in x.columns:
            dict1[column] = x[column].values.tolist()

        return dict1

    def Query_E(self):
        x = sqlContext.sql(
            " select city_name,stadium_name,SUM(extra_runs) AS Total_Extra_runs \
      FROM Entire_dataset_table GROUP BY stadium_name,city_name ORDER BY SUM(extra_runs) DESC Limit 1"
        )

        dict1 = {}  # Creating a Dictionary python object

        x = x.toPandas()

        for column in x.columns:
            dict1[column] = x[column].values.tolist()

        return dict1

    def Query_F(self):
        x = sqlContext.sql(
            "select player_of_match AS Player_name, COUNT(player_of_match) AS MOM_Awards from venue_summary_table \
      where neutral_venue = true GROUP BY player_of_match ORDER BY COUNT(player_of_match)  DESC Limit 5"
        )

        x = x.select("*").toPandas()
        result = dict(x.values)
        return result

    def Query_G(self):
        x = sqlContext.sql(
            "select  current_batsman AS Player_name , Round((sum(batsman_runs)/ sum(is_wicket)), 2 ) as Batting_average \
      from Entire_dataset_table GROUP BY current_batsman ORDER BY Batting_average DESC Limit 10"
        )

        x = x.select("*").toPandas()
        result = dict(x.values)
        return result

    def Query_H(self):
        x = sqlContext.sql(
            "select umpire1_name, Count(umpire1_name) as Total_matches from umpire_name_union_table GROUP BY umpire1_name \
      ORDER BY COUNT(umpire1_name) DESC Limit 1"
        )

        dict1 = {}  # Creating a Dictionary python object

        x = x.toPandas()

        for column in x.columns:
            dict1[column] = x[column].values.tolist()

        return dict1

    def Query_I(self):
        x = sqlContext.sql(
            ' select stadium_name,city_name,SUM(batsman_runs) As Total_Runs FROM Entire_dataset_table \
      where current_batsman = "V Kohli" GROUP BY stadium_name,city_name ORDER BY SUM(batsman_runs) DESC limit 1'
        )

        dict1 = {}  # Creating a Dictionary python object

        x = x.toPandas()

        for column in x.columns:
            dict1[column] = x[column].values.tolist()

        return dict1

    def __del__(self):
        self.conn.close()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Db = Database() # Object of class Database to implement SQL queires using class methods
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Db.get_status()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: &lt;sqlite3.Connection at 0x7fc49802ae30&gt;</div>

# %%
Db.Query_A()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: {&#39;batting_team&#39;: [&#39;Kolkata Knight Riders&#39;],
#  &#39;match_id&#39;: [335986],
#  &#39;bowling_team&#39;: [&#39;Deccan Chargers&#39;],
#  &#39;Total_Extra_Runs&#39;: [28]}</div>

# %%
# %sql
select distinct(method) from ipl_matches_csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th></tr></thead><tbody><tr><td>NA</td></tr><tr><td>D/L</td></tr></tbody></table></div>

# %% [markdown]
# # Thank You
